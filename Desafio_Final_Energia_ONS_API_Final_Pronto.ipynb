# %% [markdown]
# # Desafio Final — Análise de Dados de Energia com API Pública
#
# **Curso:** Ciência da Computação
# **Disciplina:** Soluções em Energias Renováveis e Sustentáveis
#
# ## Situação-problema
#
# Uma equipe de planejamento energético precisa analisar o comportamento da carga elétrica de uma região atendida pelo Sistema Interligado Nacional (SIN).
#
# Os dados serão obtidos diretamente de uma API pública do **Operador Nacional do Sistema Elétrico (ONS)**. A conexão com a API e a preparação inicial do JSON já estão fornecidas. A partir daí, sua equipe deverá construir o DataFrame, organizar os dados, criar recortes, calcular indicadores, produzir gráficos e elaborar um relatório técnico.
#
# > Todos os códigos, resultados, gráficos e respostas devem permanecer neste mesmo Notebook.

# %% [markdown]
# ## 1. Fonte dos dados
#
# API pública de **Carga Verificada do ONS**:
#
# - Portal: https://dados.ons.org.br/
# - Conjunto de dados: https://dados.ons.org.br/dataset/carga-energia-verificada
# - Dicionário de dados: Carga Verificada do ONS
#
# Neste notebook será utilizada inicialmente a área **SP — São Paulo**, no período de **01/08/2025 a 07/08/2025**.
#
# Os campos usados na análise seguem a estrutura da Carga Verificada do ONS: `cod_areacarga`, `dat_referencia`, `din_referenciautc`, `val_cargaglobal` e demais componentes disponibilizados pela API.

# %% [markdown]
# ## 2. Bibliotecas

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Consulta à API
#
# Esta célula está pronta. Não é necessário conhecer `requests` para realizar o desafio.

# %%
url = "https://apicarga.ons.org.br/prd/cargaverificada"

parametros = {
    "dat_inicio": "2025-08-01",
    "dat_fim": "2025-08-07",
    "cod_areacarga": "SP"
}

response = requests.get(url, params=parametros, timeout=30)

print("Status:", response.status_code)
print("URL:", response.url)

response.raise_for_status()
dados_json = response.json()
# Out:
# Status: 200
# URL: https://apicarga.ons.org.br/prd/cargaverificada?dat_inicio=2025-08-01&dat_fim=2025-08-07&cod_areacarga=SP

# %% [markdown]
# ## 4. Preparação inicial do JSON
#
# A célula abaixo localiza a lista principal de registros retornada pela API e a armazena em `registros`.

# %%
if isinstance(dados_json, list):
    registros = dados_json

elif isinstance(dados_json, dict):
    chaves_com_lista = [
        chave for chave, valor in dados_json.items()
        if isinstance(valor, list)
    ]

    if not chaves_com_lista:
        raise ValueError("A resposta não contém uma lista de registros.")

    chave_registros = chaves_com_lista[0]
    registros = dados_json[chave_registros]
    print("Chave utilizada:", chave_registros)

else:
    raise TypeError("Formato de JSON não reconhecido.")

print("Tipo:", type(registros))
print("Quantidade de registros:", len(registros))

if registros:
    print("\nPrimeiro registro:")
    print(registros[0])
# Out:
# Tipo: <class 'list'>
# Quantidade de registros: 336
#
# Primeiro registro:
# {'cod_areacarga': 'SP', 'din_atualizacao': '2026-08-14T05:58:29.574Z', 'dat_referencia': '2025-08-01', 'din_referenciautc': '2025-08-01T03:30:00.000Z', 'val_cargaglobal': 15913.618, 'val_cargaglobalcons': 15913.618, 'val_cargaglobalsmmgd': 15892.488, 'val_cargasupervisionada': 14421.112, 'val_carganaosupervisionada': 1471.3759, 'val_cargammgd': 21.13, 'val_consistencia': 0}

# %%
type(registros)
# Out:
# list

# %%
registros
# Out:
# [{'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T03:30:00.000Z',
#   'val_cargaglobal': 15913.618,
#   'val_cargaglobalcons': 15913.618,
#   'val_cargaglobalsmmgd': 15892.488,
#   'val_cargasupervisionada': 14421.112,
#   'val_carganaosupervisionada': 1471.3759,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T04:00:00.000Z',
#   'val_cargaglobal': 15251.414,
#   'val_cargaglobalcons': 15251.414,
#   'val_cargaglobalsmmgd': 15230.284,
#   'val_cargasupervisionada': 13758.101,
#   'val_carganaosupervisionada': 1472.184,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T04:30:00.000Z',
#   'val_cargaglobal': 14606.733,
#   'val_cargaglobalcons': 14606.733,
#   'val_cargaglobalsmmgd': 14585.604,
#   'val_cargasupervisionada': 13112.602,
#   'val_carganaosupervisionada': 1473.0022,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T05:00:00.000Z',
#   'val_cargaglobal': 14182.29,
#   'val_cargaglobalcons': 14182.29,
#   'val_cargaglobalsmmgd': 14161.16,
#   'val_cargasupervisionada': 12687.433,
#   'val_carganaosupervisionada': 1473.7275,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T05:30:00.000Z',
#   'val_cargaglobal': 13838.488,
#   'val_cargaglobalcons': 13838.488,
#   'val_cargaglobalsmmgd': 13817.358,
#   'val_cargasupervisionada': 12342.648,
#   'val_carganaosupervisionada': 1474.7096,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T06:00:00.000Z',
#   'val_cargaglobal': 13672.563,
#   'val_cargaglobalcons': 13672.563,
#   'val_cargaglobalsmmgd': 13651.434,
#   'val_cargasupervisionada': 12174.674,
#   'val_carganaosupervisionada': 1476.7596,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T06:30:00.000Z',
#   'val_cargaglobal': 13548.542,
#   'val_cargaglobalcons': 13548.542,
#   'val_cargaglobalsmmgd': 13527.412,
#   'val_cargasupervisionada': 12049.024,
#   'val_carganaosupervisionada': 1478.3882,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T07:00:00.000Z',
#   'val_cargaglobal': 13634.049,
#   'val_cargaglobalcons': 13634.049,
#   'val_cargaglobalsmmgd': 13612.919,
#   'val_cargasupervisionada': 12134.907,
#   'val_carganaosupervisionada': 1478.012,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T07:30:00.000Z',
#   'val_cargaglobal': 13733.728,
#   'val_cargaglobalcons': 13733.728,
#   'val_cargaglobalsmmgd': 13712.598,
#   'val_cargasupervisionada': 12235.872,
#   'val_carganaosupervisionada': 1476.7253,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T08:00:00.000Z',
#   'val_cargaglobal': 13958.203,
#   'val_cargaglobalcons': 13958.203,
#   'val_cargaglobalsmmgd': 13937.073,
#   'val_cargasupervisionada': 12461.951,
#   'val_carganaosupervisionada': 1475.122,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T08:30:00.000Z',
#   'val_cargaglobal': 14637.415,
#   'val_cargaglobalcons': 14637.415,
#   'val_cargaglobalsmmgd': 14616.285,
#   'val_cargasupervisionada': 13143.165,
#   'val_carganaosupervisionada': 1473.12,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T09:00:00.000Z',
#   'val_cargaglobal': 15389.913,
#   'val_cargaglobalcons': 15389.913,
#   'val_cargaglobalsmmgd': 15368.783,
#   'val_cargasupervisionada': 13898.176,
#   'val_carganaosupervisionada': 1470.6072,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T09:30:00.000Z',
#   'val_cargaglobal': 16570.408,
#   'val_cargaglobalcons': 16570.408,
#   'val_cargaglobalsmmgd': 16549.277,
#   'val_cargasupervisionada': 15081.01,
#   'val_carganaosupervisionada': 1468.2671,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T10:00:00.000Z',
#   'val_cargaglobal': 16844.27,
#   'val_cargaglobalcons': 16844.27,
#   'val_cargaglobalsmmgd': 16803.602,
#   'val_cargasupervisionada': 15336.101,
#   'val_carganaosupervisionada': 1467.502,
#   'val_cargammgd': 40.6685,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T10:30:00.000Z',
#   'val_cargaglobal': 17564.123,
#   'val_cargaglobalcons': 17564.123,
#   'val_cargaglobalsmmgd': 17240.445,
#   'val_cargasupervisionada': 15774.4,
#   'val_carganaosupervisionada': 1466.044,
#   'val_cargammgd': 323.6768,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T11:00:00.000Z',
#   'val_cargaglobal': 18096.023,
#   'val_cargaglobalcons': 18096.023,
#   'val_cargaglobalsmmgd': 17415.6,
#   'val_cargasupervisionada': 15954.084,
#   'val_carganaosupervisionada': 1461.5154,
#   'val_cargammgd': 680.4232,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T11:30:00.000Z',
#   'val_cargaglobal': 18629.395,
#   'val_cargaglobalcons': 18629.395,
#   'val_cargaglobalsmmgd': 17409.6,
#   'val_cargasupervisionada': 15953.951,
#   'val_carganaosupervisionada': 1455.6488,
#   'val_cargammgd': 1219.7958,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T12:00:00.000Z',
#   'val_cargaglobal': 18825.176,
#   'val_cargaglobalcons': 18825.176,
#   'val_cargaglobalsmmgd': 17097.592,
#   'val_cargasupervisionada': 15648.688,
#   'val_carganaosupervisionada': 1448.904,
#   'val_cargammgd': 1727.5842,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T12:30:00.000Z',
#   'val_cargaglobal': 19056.504,
#   'val_cargaglobalcons': 19056.504,
#   'val_cargaglobalsmmgd': 16850.477,
#   'val_cargasupervisionada': 15407.757,
#   'val_carganaosupervisionada': 1442.7206,
#   'val_cargammgd': 2206.0276,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T13:00:00.000Z',
#   'val_cargaglobal': 19427.822,
#   'val_cargaglobalcons': 19427.822,
#   'val_cargaglobalsmmgd': 16792.59,
#   'val_cargasupervisionada': 15353.431,
#   'val_carganaosupervisionada': 1439.1598,
#   'val_cargammgd': 2635.2324,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T13:30:00.000Z',
#   'val_cargaglobal': 19648.512,
#   'val_cargaglobalcons': 19648.512,
#   'val_cargaglobalsmmgd': 16638.367,
#   'val_cargasupervisionada': 15201.553,
#   'val_carganaosupervisionada': 1436.8154,
#   'val_cargammgd': 3010.1455,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T14:00:00.000Z',
#   'val_cargaglobal': 19987.754,
#   'val_cargaglobalcons': 19987.754,
#   'val_cargaglobalsmmgd': 16673.879,
#   'val_cargasupervisionada': 15239.052,
#   'val_carganaosupervisionada': 1434.8273,
#   'val_cargammgd': 3313.8745,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T14:30:00.000Z',
#   'val_cargaglobal': 20126.986,
#   'val_cargaglobalcons': 20126.986,
#   'val_cargaglobalsmmgd': 16588.04,
#   'val_cargasupervisionada': 15154.42,
#   'val_carganaosupervisionada': 1433.6187,
#   'val_cargammgd': 3538.9473,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T15:00:00.000Z',
#   'val_cargaglobal': 20126.97,
#   'val_cargaglobalcons': 20126.97,
#   'val_cargaglobalsmmgd': 16446.277,
#   'val_cargasupervisionada': 15013.091,
#   'val_carganaosupervisionada': 1433.1873,
#   'val_cargammgd': 3680.6926,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T15:30:00.000Z',
#   'val_cargaglobal': 19785.258,
#   'val_cargaglobalcons': 19785.258,
#   'val_cargaglobalsmmgd': 16049.248,
#   'val_cargasupervisionada': 14616.108,
#   'val_carganaosupervisionada': 1433.1396,
#   'val_cargammgd': 3736.0098,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T16:00:00.000Z',
#   'val_cargaglobal': 19630.8,
#   'val_cargaglobalcons': 19630.8,
#   'val_cargaglobalsmmgd': 15926.451,
#   'val_cargasupervisionada': 14492.658,
#   'val_carganaosupervisionada': 1433.7927,
#   'val_cargammgd': 3704.3503,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T16:30:00.000Z',
#   'val_cargaglobal': 19944.734,
#   'val_cargaglobalcons': 19944.734,
#   'val_cargaglobalsmmgd': 16358.286,
#   'val_cargasupervisionada': 14924.406,
#   'val_carganaosupervisionada': 1433.8798,
#   'val_cargammgd': 3586.448,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T17:00:00.000Z',
#   'val_cargaglobal': 20101.248,
#   'val_cargaglobalcons': 20101.248,
#   'val_cargaglobalsmmgd': 16715.695,
#   'val_cargasupervisionada': 15284.566,
#   'val_carganaosupervisionada': 1431.1292,
#   'val_cargammgd': 3385.552,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T17:30:00.000Z',
#   'val_cargaglobal': 20149.096,
#   'val_cargaglobalcons': 20149.096,
#   'val_cargaglobalsmmgd': 17042.973,
#   'val_cargasupervisionada': 15614.157,
#   'val_carganaosupervisionada': 1428.8147,
#   'val_cargammgd': 3106.1228,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T18:00:00.000Z',
#   'val_cargaglobal': 20149.994,
#   'val_cargaglobalcons': 20149.994,
#   'val_cargaglobalsmmgd': 17394.816,
#   'val_cargasupervisionada': 15966.112,
#   'val_carganaosupervisionada': 1428.7037,
#   'val_cargammgd': 2755.177,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T18:30:00.000Z',
#   'val_cargaglobal': 20156.96,
#   'val_cargaglobalcons': 20156.96,
#   'val_cargaglobalsmmgd': 17816.303,
#   'val_cargasupervisionada': 16387.63,
#   'val_carganaosupervisionada': 1428.6711,
#   'val_cargammgd': 2340.6584,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T19:00:00.000Z',
#   'val_cargaglobal': 20130.299,
#   'val_cargaglobalcons': 20130.299,
#   'val_cargaglobalsmmgd': 18249.098,
#   'val_cargasupervisionada': 16821.352,
#   'val_carganaosupervisionada': 1427.7465,
#   'val_cargammgd': 1881.2015,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T19:30:00.000Z',
#   'val_cargaglobal': 20111.898,
#   'val_cargaglobalcons': 20111.898,
#   'val_cargaglobalsmmgd': 18732.162,
#   'val_cargasupervisionada': 17304.648,
#   'val_carganaosupervisionada': 1427.5135,
#   'val_cargammgd': 1379.7368,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T20:00:00.000Z',
#   'val_cargaglobal': 20268.64,
#   'val_cargaglobalcons': 20268.64,
#   'val_cargaglobalsmmgd': 19388.738,
#   'val_cargasupervisionada': 17958.64,
#   'val_carganaosupervisionada': 1430.0977,
#   'val_cargammgd': 879.9032,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T20:30:00.000Z',
#   'val_cargaglobal': 20384.635,
#   'val_cargaglobalcons': 20384.635,
#   'val_cargaglobalsmmgd': 20019.814,
#   'val_cargasupervisionada': 18585.818,
#   'val_carganaosupervisionada': 1433.9957,
#   'val_cargammgd': 364.8194,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T21:00:00.000Z',
#   'val_cargaglobal': 21088.959,
#   'val_cargaglobalcons': 21088.959,
#   'val_cargaglobalsmmgd': 20955.12,
#   'val_cargasupervisionada': 19516.37,
#   'val_carganaosupervisionada': 1438.7495,
#   'val_cargammgd': 133.8406,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T21:30:00.000Z',
#   'val_cargaglobal': 22398.36,
#   'val_cargaglobalcons': 22398.36,
#   'val_cargaglobalsmmgd': 22377.096,
#   'val_cargasupervisionada': 20933.746,
#   'val_carganaosupervisionada': 1443.3496,
#   'val_cargammgd': 21.2638,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T22:00:00.000Z',
#   'val_cargaglobal': 23185.312,
#   'val_cargaglobalcons': 23185.312,
#   'val_cargaglobalsmmgd': 23164.182,
#   'val_cargasupervisionada': 21717.934,
#   'val_carganaosupervisionada': 1446.2487,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T22:30:00.000Z',
#   'val_cargaglobal': 22903.314,
#   'val_cargaglobalcons': 22903.314,
#   'val_cargaglobalsmmgd': 22882.184,
#   'val_cargasupervisionada': 21433.58,
#   'val_carganaosupervisionada': 1448.6025,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T23:00:00.000Z',
#   'val_cargaglobal': 22358.701,
#   'val_cargaglobalcons': 22358.701,
#   'val_cargaglobalsmmgd': 22337.57,
#   'val_cargasupervisionada': 20886.078,
#   'val_carganaosupervisionada': 1451.4915,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-01T23:30:00.000Z',
#   'val_cargaglobal': 21697.979,
#   'val_cargaglobalcons': 21697.979,
#   'val_cargaglobalsmmgd': 21676.848,
#   'val_cargasupervisionada': 20223.252,
#   'val_carganaosupervisionada': 1453.5953,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-02T00:00:00.000Z',
#   'val_cargaglobal': 21385.326,
#   'val_cargaglobalcons': 21385.326,
#   'val_cargaglobalsmmgd': 21364.195,
#   'val_cargasupervisionada': 19911.168,
#   'val_carganaosupervisionada': 1453.0271,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-02T00:30:00.000Z',
#   'val_cargaglobal': 20919.314,
#   'val_cargaglobalcons': 20919.314,
#   'val_cargaglobalsmmgd': 20898.184,
#   'val_cargasupervisionada': 19445.617,
#   'val_carganaosupervisionada': 1452.5674,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-02T01:00:00.000Z',
#   'val_cargaglobal': 20234.748,
#   'val_cargaglobalcons': 20234.748,
#   'val_cargaglobalsmmgd': 20213.617,
#   'val_cargasupervisionada': 18758.58,
#   'val_carganaosupervisionada': 1455.0361,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-02T01:30:00.000Z',
#   'val_cargaglobal': 19448.836,
#   'val_cargaglobalcons': 19448.836,
#   'val_cargaglobalsmmgd': 19427.705,
#   'val_cargasupervisionada': 17969.277,
#   'val_carganaosupervisionada': 1458.4272,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-02T02:00:00.000Z',
#   'val_cargaglobal': 18866.266,
#   'val_cargaglobalcons': 18866.266,
#   'val_cargaglobalsmmgd': 18845.135,
#   'val_cargasupervisionada': 17385.73,
#   'val_carganaosupervisionada': 1459.4052,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-02T02:30:00.000Z',
#   'val_cargaglobal': 17996.322,
#   'val_cargaglobalcons': 17996.322,
#   'val_cargaglobalsmmgd': 17975.191,
#   'val_cargasupervisionada': 16510.412,
#   'val_carganaosupervisionada': 1464.7788,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:29.574Z',
#   'dat_referencia': '2025-08-01',
#   'din_referenciautc': '2025-08-02T03:00:00.000Z',
#   'val_cargaglobal': 17207.49,
#   'val_cargaglobalcons': 17207.49,
#   'val_cargaglobalsmmgd': 17186.36,
#   'val_cargasupervisionada': 15698.728,
#   'val_carganaosupervisionada': 1487.6323,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T03:30:00.000Z',
#   'val_cargaglobal': 16420.523,
#   'val_cargaglobalcons': 16420.523,
#   'val_cargaglobalsmmgd': 16399.393,
#   'val_cargasupervisionada': 14893.586,
#   'val_carganaosupervisionada': 1505.806,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T04:00:00.000Z',
#   'val_cargaglobal': 15758.82,
#   'val_cargaglobalcons': 15758.82,
#   'val_cargaglobalsmmgd': 15737.69,
#   'val_cargasupervisionada': 14230.481,
#   'val_carganaosupervisionada': 1507.2089,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T04:30:00.000Z',
#   'val_cargaglobal': 15070.9795,
#   'val_cargaglobalcons': 15070.9795,
#   'val_cargaglobalsmmgd': 15049.85,
#   'val_cargasupervisionada': 13542.382,
#   'val_carganaosupervisionada': 1507.4681,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T05:00:00.000Z',
#   'val_cargaglobal': 14550.781,
#   'val_cargaglobalcons': 14550.781,
#   'val_cargaglobalsmmgd': 14529.651,
#   'val_cargasupervisionada': 13021.605,
#   'val_carganaosupervisionada': 1508.0457,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T05:30:00.000Z',
#   'val_cargaglobal': 14149.084,
#   'val_cargaglobalcons': 14149.084,
#   'val_cargaglobalsmmgd': 14127.954,
#   'val_cargasupervisionada': 12618.741,
#   'val_carganaosupervisionada': 1509.2126,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T06:00:00.000Z',
#   'val_cargaglobal': 13894.754,
#   'val_cargaglobalcons': 13894.754,
#   'val_cargaglobalsmmgd': 13873.624,
#   'val_cargasupervisionada': 12362.313,
#   'val_carganaosupervisionada': 1511.3108,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T06:30:00.000Z',
#   'val_cargaglobal': 13768.955,
#   'val_cargaglobalcons': 13768.955,
#   'val_cargaglobalsmmgd': 13747.825,
#   'val_cargasupervisionada': 12234.847,
#   'val_carganaosupervisionada': 1512.9781,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T07:00:00.000Z',
#   'val_cargaglobal': 13672.503,
#   'val_cargaglobalcons': 13672.503,
#   'val_cargaglobalsmmgd': 13651.373,
#   'val_cargasupervisionada': 12138.78,
#   'val_carganaosupervisionada': 1512.5933,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T07:30:00.000Z',
#   'val_cargaglobal': 13684.376,
#   'val_cargaglobalcons': 13684.376,
#   'val_cargaglobalsmmgd': 13663.246,
#   'val_cargasupervisionada': 12151.97,
#   'val_carganaosupervisionada': 1511.2762,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T08:00:00.000Z',
#   'val_cargaglobal': 13722.082,
#   'val_cargaglobalcons': 13722.082,
#   'val_cargaglobalsmmgd': 13700.952,
#   'val_cargasupervisionada': 12191.317,
#   'val_carganaosupervisionada': 1509.6345,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T08:30:00.000Z',
#   'val_cargaglobal': 13882.396,
#   'val_cargaglobalcons': 13882.396,
#   'val_cargaglobalsmmgd': 13861.267,
#   'val_cargasupervisionada': 12353.682,
#   'val_carganaosupervisionada': 1507.5847,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T09:00:00.000Z',
#   'val_cargaglobal': 14046.323,
#   'val_cargaglobalcons': 14046.323,
#   'val_cargaglobalsmmgd': 14025.193,
#   'val_cargasupervisionada': 12520.182,
#   'val_carganaosupervisionada': 1505.0117,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T09:30:00.000Z',
#   'val_cargaglobal': 14460.587,
#   'val_cargaglobalcons': 14460.587,
#   'val_cargaglobalsmmgd': 14439.457,
#   'val_cargasupervisionada': 12936.839,
#   'val_carganaosupervisionada': 1502.6177,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T10:00:00.000Z',
#   'val_cargaglobal': 14471.026,
#   'val_cargaglobalcons': 14471.026,
#   'val_cargaglobalsmmgd': 14428.095,
#   'val_cargasupervisionada': 12926.253,
#   'val_carganaosupervisionada': 1501.8422,
#   'val_cargammgd': 42.932,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T10:30:00.000Z',
#   'val_cargaglobal': 15066.07,
#   'val_cargaglobalcons': 15066.07,
#   'val_cargaglobalsmmgd': 14737.712,
#   'val_cargasupervisionada': 13237.354,
#   'val_carganaosupervisionada': 1500.3582,
#   'val_cargammgd': 328.3582,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T11:00:00.000Z',
#   'val_cargaglobal': 15575.346,
#   'val_cargaglobalcons': 15575.346,
#   'val_cargaglobalsmmgd': 14890.544,
#   'val_cargasupervisionada': 13394.818,
#   'val_carganaosupervisionada': 1495.7257,
#   'val_cargammgd': 684.8018,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T11:30:00.000Z',
#   'val_cargaglobal': 16097.26,
#   'val_cargaglobalcons': 16097.26,
#   'val_cargaglobalsmmgd': 14881.158,
#   'val_cargasupervisionada': 13391.437,
#   'val_carganaosupervisionada': 1489.7218,
#   'val_cargammgd': 1216.1019,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T12:00:00.000Z',
#   'val_cargaglobal': 16455.287,
#   'val_cargaglobalcons': 16455.287,
#   'val_cargaglobalsmmgd': 14745.81,
#   'val_cargasupervisionada': 13262.991,
#   'val_carganaosupervisionada': 1482.8187,
#   'val_cargammgd': 1709.4781,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T12:30:00.000Z',
#   'val_cargaglobal': 16785.87,
#   'val_cargaglobalcons': 16785.87,
#   'val_cargaglobalsmmgd': 14618.361,
#   'val_cargasupervisionada': 13141.872,
#   'val_carganaosupervisionada': 1476.4897,
#   'val_cargammgd': 2167.5078,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T13:00:00.000Z',
#   'val_cargaglobal': 17139.791,
#   'val_cargaglobalcons': 17139.791,
#   'val_cargaglobalsmmgd': 14546.778,
#   'val_cargasupervisionada': 13073.933,
#   'val_carganaosupervisionada': 1472.846,
#   'val_cargammgd': 2593.0122,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T13:30:00.000Z',
#   'val_cargaglobal': 17415.373,
#   'val_cargaglobalcons': 17415.373,
#   'val_cargaglobalsmmgd': 14435.566,
#   'val_cargasupervisionada': 12965.119,
#   'val_carganaosupervisionada': 1470.4475,
#   'val_cargammgd': 2979.8071,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T14:00:00.000Z',
#   'val_cargaglobal': 17699.064,
#   'val_cargaglobalcons': 17699.064,
#   'val_cargaglobalsmmgd': 14434.331,
#   'val_cargasupervisionada': 12965.917,
#   'val_carganaosupervisionada': 1468.4142,
#   'val_cargammgd': 3264.733,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T14:30:00.000Z',
#   'val_cargaglobal': 17838.99,
#   'val_cargaglobalcons': 17838.99,
#   'val_cargaglobalsmmgd': 14397.841,
#   'val_cargasupervisionada': 12930.662,
#   'val_carganaosupervisionada': 1467.179,
#   'val_cargammgd': 3441.15,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T15:00:00.000Z',
#   'val_cargaglobal': 18035.479,
#   'val_cargaglobalcons': 18035.479,
#   'val_cargaglobalsmmgd': 14461.048,
#   'val_cargasupervisionada': 12994.31,
#   'val_carganaosupervisionada': 1466.7385,
#   'val_cargammgd': 3574.4302,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T15:30:00.000Z',
#   'val_cargaglobal': 18109.52,
#   'val_cargaglobalcons': 18109.52,
#   'val_cargaglobalsmmgd': 14447.273,
#   'val_cargasupervisionada': 12980.584,
#   'val_carganaosupervisionada': 1466.69,
#   'val_cargammgd': 3662.2466,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T16:00:00.000Z',
#   'val_cargaglobal': 18165.633,
#   'val_cargaglobalcons': 18165.633,
#   'val_cargaglobalsmmgd': 14532.819,
#   'val_cargasupervisionada': 13065.461,
#   'val_carganaosupervisionada': 1467.3586,
#   'val_cargammgd': 3632.8132,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T16:30:00.000Z',
#   'val_cargaglobal': 18116.396,
#   'val_cargaglobalcons': 18116.396,
#   'val_cargaglobalsmmgd': 14630.89,
#   'val_cargasupervisionada': 13163.442,
#   'val_carganaosupervisionada': 1467.4475,
#   'val_cargammgd': 3485.5076,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T17:00:00.000Z',
#   'val_cargaglobal': 18026.918,
#   'val_cargaglobalcons': 18026.918,
#   'val_cargaglobalsmmgd': 14752.385,
#   'val_cargasupervisionada': 13287.752,
#   'val_carganaosupervisionada': 1464.6329,
#   'val_cargammgd': 3274.5325,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T17:30:00.000Z',
#   'val_cargaglobal': 17901.504,
#   'val_cargaglobalcons': 17901.504,
#   'val_cargaglobalsmmgd': 14895.603,
#   'val_cargasupervisionada': 13433.341,
#   'val_carganaosupervisionada': 1462.262,
#   'val_cargammgd': 3005.901,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T18:00:00.000Z',
#   'val_cargaglobal': 17893.06,
#   'val_cargaglobalcons': 17893.06,
#   'val_cargaglobalsmmgd': 15239.081,
#   'val_cargasupervisionada': 13776.936,
#   'val_carganaosupervisionada': 1462.1453,
#   'val_cargammgd': 2653.979,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T18:30:00.000Z',
#   'val_cargaglobal': 17818.62,
#   'val_cargaglobalcons': 17818.62,
#   'val_cargaglobalsmmgd': 15592.893,
#   'val_cargasupervisionada': 14130.782,
#   'val_carganaosupervisionada': 1462.1108,
#   'val_cargammgd': 2225.7263,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T19:00:00.000Z',
#   'val_cargaglobal': 17811.816,
#   'val_cargaglobalcons': 17811.816,
#   'val_cargaglobalsmmgd': 16046.882,
#   'val_cargasupervisionada': 14585.722,
#   'val_carganaosupervisionada': 1461.1598,
#   'val_cargammgd': 1764.9338,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T19:30:00.000Z',
#   'val_cargaglobal': 17947.926,
#   'val_cargaglobalcons': 17947.926,
#   'val_cargaglobalsmmgd': 16673.215,
#   'val_cargasupervisionada': 15212.3,
#   'val_carganaosupervisionada': 1460.9154,
#   'val_cargammgd': 1274.711,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T20:00:00.000Z',
#   'val_cargaglobal': 18231.777,
#   'val_cargaglobalcons': 18231.777,
#   'val_cargaglobalsmmgd': 17427.168,
#   'val_cargasupervisionada': 15963.613,
#   'val_carganaosupervisionada': 1463.5555,
#   'val_cargammgd': 804.6089,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T20:30:00.000Z',
#   'val_cargaglobal': 18574.22,
#   'val_cargaglobalcons': 18574.22,
#   'val_cargaglobalsmmgd': 18241.605,
#   'val_cargasupervisionada': 16774.064,
#   'val_carganaosupervisionada': 1467.5417,
#   'val_cargammgd': 332.6145,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T21:00:00.000Z',
#   'val_cargaglobal': 19554.795,
#   'val_cargaglobalcons': 19554.795,
#   'val_cargaglobalsmmgd': 19432.03,
#   'val_cargasupervisionada': 17959.623,
#   'val_carganaosupervisionada': 1472.4056,
#   'val_cargammgd': 122.7655,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T21:30:00.000Z',
#   'val_cargaglobal': 20983.484,
#   'val_cargaglobalcons': 20983.484,
#   'val_cargaglobalsmmgd': 20962.176,
#   'val_cargasupervisionada': 19485.06,
#   'val_carganaosupervisionada': 1477.1143,
#   'val_cargammgd': 21.308,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T22:00:00.000Z',
#   'val_cargaglobal': 21202.566,
#   'val_cargaglobalcons': 21202.566,
#   'val_cargaglobalsmmgd': 21181.436,
#   'val_cargasupervisionada': 19701.352,
#   'val_carganaosupervisionada': 1480.0841,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T22:30:00.000Z',
#   'val_cargaglobal': 20717.08,
#   'val_cargaglobalcons': 20717.08,
#   'val_cargaglobalsmmgd': 20695.95,
#   'val_cargasupervisionada': 19213.453,
#   'val_carganaosupervisionada': 1482.4965,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T23:00:00.000Z',
#   'val_cargaglobal': 20093.822,
#   'val_cargaglobalcons': 20093.822,
#   'val_cargaglobalsmmgd': 20072.691,
#   'val_cargasupervisionada': 18587.236,
#   'val_carganaosupervisionada': 1485.4545,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-02T23:30:00.000Z',
#   'val_cargaglobal': 19481.361,
#   'val_cargaglobalcons': 19481.361,
#   'val_cargaglobalsmmgd': 19460.23,
#   'val_cargasupervisionada': 17972.623,
#   'val_carganaosupervisionada': 1487.6083,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-03T00:00:00.000Z',
#   'val_cargaglobal': 18928.691,
#   'val_cargaglobalcons': 18928.691,
#   'val_cargaglobalsmmgd': 18907.56,
#   'val_cargasupervisionada': 17420.533,
#   'val_carganaosupervisionada': 1487.0277,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-03T00:30:00.000Z',
#   'val_cargaglobal': 18643.072,
#   'val_cargaglobalcons': 18643.072,
#   'val_cargaglobalsmmgd': 18621.941,
#   'val_cargasupervisionada': 17135.383,
#   'val_carganaosupervisionada': 1486.5577,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-03T01:00:00.000Z',
#   'val_cargaglobal': 18060.94,
#   'val_cargaglobalcons': 18060.94,
#   'val_cargaglobalsmmgd': 18039.809,
#   'val_cargasupervisionada': 16550.725,
#   'val_carganaosupervisionada': 1489.0846,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-03T01:30:00.000Z',
#   'val_cargaglobal': 17281.04,
#   'val_cargaglobalcons': 17281.04,
#   'val_cargaglobalsmmgd': 17259.908,
#   'val_cargasupervisionada': 15767.353,
#   'val_carganaosupervisionada': 1492.5553,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-03T02:00:00.000Z',
#   'val_cargaglobal': 16650.99,
#   'val_cargaglobalcons': 16650.99,
#   'val_cargaglobalsmmgd': 16629.86,
#   'val_cargasupervisionada': 15135.687,
#   'val_carganaosupervisionada': 1494.1725,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-03T02:30:00.000Z',
#   'val_cargaglobal': 16140.681,
#   'val_cargaglobalcons': 16140.681,
#   'val_cargaglobalsmmgd': 16119.551,
#   'val_cargasupervisionada': 14620.496,
#   'val_carganaosupervisionada': 1499.055,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:37.837Z',
#   'dat_referencia': '2025-08-02',
#   'din_referenciautc': '2025-08-03T03:00:00.000Z',
#   'val_cargaglobal': 15395.828,
#   'val_cargaglobalcons': 15395.828,
#   'val_cargaglobalsmmgd': 15374.698,
#   'val_cargasupervisionada': 13857.772,
#   'val_carganaosupervisionada': 1516.9261,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T03:30:00.000Z',
#   'val_cargaglobal': 14768.362,
#   'val_cargaglobalcons': 14768.362,
#   'val_cargaglobalsmmgd': 14747.232,
#   'val_cargasupervisionada': 13216.058,
#   'val_carganaosupervisionada': 1531.1752,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T04:00:00.000Z',
#   'val_cargaglobal': 14164.812,
#   'val_cargaglobalcons': 14164.812,
#   'val_cargaglobalsmmgd': 14143.682,
#   'val_cargasupervisionada': 12611.155,
#   'val_carganaosupervisionada': 1532.526,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T04:30:00.000Z',
#   'val_cargaglobal': 13575.32,
#   'val_cargaglobalcons': 13575.32,
#   'val_cargaglobalsmmgd': 13554.19,
#   'val_cargasupervisionada': 12021.4,
#   'val_carganaosupervisionada': 1532.7904,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T05:00:00.000Z',
#   'val_cargaglobal': 13120.288,
#   'val_cargaglobalcons': 13120.288,
#   'val_cargaglobalsmmgd': 13099.158,
#   'val_cargasupervisionada': 11565.794,
#   'val_carganaosupervisionada': 1533.3647,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T05:30:00.000Z',
#   'val_cargaglobal': 12757.054,
#   'val_cargaglobalcons': 12757.054,
#   'val_cargaglobalsmmgd': 12735.924,
#   'val_cargasupervisionada': 11201.418,
#   'val_carganaosupervisionada': 1534.5056,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T06:00:00.000Z',
#   'val_cargaglobal': 12522.124,
#   'val_cargaglobalcons': 12522.124,
#   'val_cargaglobalsmmgd': 12500.994,
#   'val_cargasupervisionada': 10964.39,
#   'val_carganaosupervisionada': 1536.604,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T06:30:00.000Z',
#   'val_cargaglobal': 12337.943,
#   'val_cargaglobalcons': 12337.943,
#   'val_cargaglobalsmmgd': 12316.813,
#   'val_cargasupervisionada': 10778.539,
#   'val_carganaosupervisionada': 1538.2747,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T07:00:00.000Z',
#   'val_cargaglobal': 12172.875,
#   'val_cargaglobalcons': 12172.875,
#   'val_cargaglobalsmmgd': 12151.745,
#   'val_cargasupervisionada': 10613.8545,
#   'val_carganaosupervisionada': 1537.8904,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T07:30:00.000Z',
#   'val_cargaglobal': 12141.661,
#   'val_cargaglobalcons': 12141.661,
#   'val_cargaglobalsmmgd': 12120.531,
#   'val_cargasupervisionada': 10583.963,
#   'val_carganaosupervisionada': 1536.5688,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T08:00:00.000Z',
#   'val_cargaglobal': 12141.932,
#   'val_cargaglobalcons': 12141.932,
#   'val_cargaglobalsmmgd': 12120.802,
#   'val_cargasupervisionada': 10585.89,
#   'val_carganaosupervisionada': 1534.9119,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T08:30:00.000Z',
#   'val_cargaglobal': 12155.519,
#   'val_cargaglobalcons': 12155.519,
#   'val_cargaglobalsmmgd': 12134.389,
#   'val_cargasupervisionada': 10601.549,
#   'val_carganaosupervisionada': 1532.8398,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T09:00:00.000Z',
#   'val_cargaglobal': 12245.285,
#   'val_cargaglobalcons': 12245.285,
#   'val_cargaglobalsmmgd': 12224.155,
#   'val_cargasupervisionada': 10693.922,
#   'val_carganaosupervisionada': 1530.233,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T09:30:00.000Z',
#   'val_cargaglobal': 12354.054,
#   'val_cargaglobalcons': 12354.054,
#   'val_cargaglobalsmmgd': 12332.924,
#   'val_cargasupervisionada': 10805.109,
#   'val_carganaosupervisionada': 1527.8143,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T10:00:00.000Z',
#   'val_cargaglobal': 12139.253,
#   'val_cargaglobalcons': 12139.253,
#   'val_cargaglobalsmmgd': 12094.705,
#   'val_cargasupervisionada': 10567.645,
#   'val_carganaosupervisionada': 1527.0602,
#   'val_cargammgd': 44.5474,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T10:30:00.000Z',
#   'val_cargaglobal': 12350.9,
#   'val_cargaglobalcons': 12350.9,
#   'val_cargaglobalsmmgd': 12023.451,
#   'val_cargasupervisionada': 10497.86,
#   'val_carganaosupervisionada': 1525.5911,
#   'val_cargammgd': 327.449,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T11:00:00.000Z',
#   'val_cargaglobal': 12614.75,
#   'val_cargaglobalcons': 12614.75,
#   'val_cargaglobalsmmgd': 11936.079,
#   'val_cargasupervisionada': 10415.158,
#   'val_carganaosupervisionada': 1520.9213,
#   'val_cargammgd': 678.671,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T11:30:00.000Z',
#   'val_cargaglobal': 13113.889,
#   'val_cargaglobalcons': 13113.889,
#   'val_cargaglobalsmmgd': 11915.4,
#   'val_cargasupervisionada': 10400.556,
#   'val_carganaosupervisionada': 1514.8452,
#   'val_cargammgd': 1198.4882,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T12:00:00.000Z',
#   'val_cargaglobal': 13403.309,
#   'val_cargaglobalcons': 13403.309,
#   'val_cargaglobalsmmgd': 11720.217,
#   'val_cargasupervisionada': 10212.3955,
#   'val_carganaosupervisionada': 1507.8217,
#   'val_cargammgd': 1683.0919,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T12:30:00.000Z',
#   'val_cargaglobal': 13791.408,
#   'val_cargaglobalcons': 13791.408,
#   'val_cargaglobalsmmgd': 11657.116,
#   'val_cargasupervisionada': 10155.745,
#   'val_carganaosupervisionada': 1501.3711,
#   'val_cargammgd': 2134.2922,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T13:00:00.000Z',
#   'val_cargaglobal': 14142.824,
#   'val_cargaglobalcons': 14142.824,
#   'val_cargaglobalsmmgd': 11593.316,
#   'val_cargasupervisionada': 10095.659,
#   'val_carganaosupervisionada': 1497.6569,
#   'val_cargammgd': 2549.5078,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T13:30:00.000Z',
#   'val_cargaglobal': 14474.791,
#   'val_cargaglobalcons': 14474.791,
#   'val_cargaglobalsmmgd': 11549.664,
#   'val_cargasupervisionada': 10054.455,
#   'val_carganaosupervisionada': 1495.2095,
#   'val_cargammgd': 2925.1267,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T14:00:00.000Z',
#   'val_cargaglobal': 14907.258,
#   'val_cargaglobalcons': 14907.258,
#   'val_cargaglobalsmmgd': 11683.964,
#   'val_cargasupervisionada': 10190.847,
#   'val_carganaosupervisionada': 1493.1168,
#   'val_cargammgd': 3223.2935,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T14:30:00.000Z',
#   'val_cargaglobal': 15355.177,
#   'val_cargaglobalcons': 15355.177,
#   'val_cargaglobalsmmgd': 11919.649,
#   'val_cargasupervisionada': 10427.779,
#   'val_carganaosupervisionada': 1491.87,
#   'val_cargammgd': 3435.5276,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:58:45.937Z',
#   'dat_referencia': '2025-08-03',
#   'din_referenciautc': '2025-08-03T15:00:00.000Z',
#   'val_cargaglobal': 15600.771,
#   'val_cargaglobalcons': 15600.771,
#   'val_cargaglobalsmmgd': 12050.06,
#   'val_cargasupervisionada': 10558.604,
#   'val_carganaosupervisionada': 1491.4564,
#   'val_cargammgd': 3550.7124,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
# ...
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T07:30:00.000Z',
#   'val_cargaglobal': 13984.083,
#   'val_cargaglobalcons': 13984.083,
#   'val_cargaglobalsmmgd': 13962.953,
#   'val_cargasupervisionada': 12523.112,
#   'val_carganaosupervisionada': 1439.8407,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T08:00:00.000Z',
#   'val_cargaglobal': 14263.655,
#   'val_cargaglobalcons': 14263.655,
#   'val_cargaglobalsmmgd': 14242.525,
#   'val_cargasupervisionada': 12804.241,
#   'val_carganaosupervisionada': 1438.2845,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T08:30:00.000Z',
#   'val_cargaglobal': 14908.752,
#   'val_cargaglobalcons': 14908.752,
#   'val_cargaglobalsmmgd': 14887.622,
#   'val_cargasupervisionada': 13451.282,
#   'val_carganaosupervisionada': 1436.3396,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T09:00:00.000Z',
#   'val_cargaglobal': 15844.801,
#   'val_cargaglobalcons': 15844.801,
#   'val_cargaglobalsmmgd': 15823.671,
#   'val_cargasupervisionada': 14389.774,
#   'val_carganaosupervisionada': 1433.8967,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T09:30:00.000Z',
#   'val_cargaglobal': 17206.496,
#   'val_cargaglobalcons': 17206.496,
#   'val_cargaglobalsmmgd': 17185.365,
#   'val_cargasupervisionada': 15753.748,
#   'val_carganaosupervisionada': 1431.618,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T10:00:00.000Z',
#   'val_cargaglobal': 17379.4,
#   'val_cargaglobalcons': 17379.4,
#   'val_cargaglobalsmmgd': 17331.717,
#   'val_cargasupervisionada': 15900.855,
#   'val_carganaosupervisionada': 1430.8617,
#   'val_cargammgd': 47.6836,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T10:30:00.000Z',
#   'val_cargaglobal': 18048.643,
#   'val_cargaglobalcons': 18048.643,
#   'val_cargaglobalsmmgd': 17732.098,
#   'val_cargasupervisionada': 16302.668,
#   'val_carganaosupervisionada': 1429.4307,
#   'val_cargammgd': 316.5445,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T11:00:00.000Z',
#   'val_cargaglobal': 18535.771,
#   'val_cargaglobalcons': 18535.771,
#   'val_cargaglobalsmmgd': 17890.176,
#   'val_cargasupervisionada': 16465.152,
#   'val_carganaosupervisionada': 1425.0228,
#   'val_cargammgd': 645.5955,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T11:30:00.000Z',
#   'val_cargaglobal': 18954.574,
#   'val_cargaglobalcons': 18954.574,
#   'val_cargaglobalsmmgd': 17823.176,
#   'val_cargasupervisionada': 16403.863,
#   'val_carganaosupervisionada': 1419.3119,
#   'val_cargammgd': 1131.3978,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T12:00:00.000Z',
#   'val_cargaglobal': 19261.451,
#   'val_cargaglobalcons': 19261.451,
#   'val_cargaglobalsmmgd': 17626.229,
#   'val_cargasupervisionada': 16213.493,
#   'val_carganaosupervisionada': 1412.7346,
#   'val_cargammgd': 1635.2222,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T12:30:00.000Z',
#   'val_cargaglobal': 19414.28,
#   'val_cargaglobalcons': 19414.28,
#   'val_cargaglobalsmmgd': 17244.285,
#   'val_cargasupervisionada': 15837.585,
#   'val_carganaosupervisionada': 1406.7012,
#   'val_cargammgd': 2169.9944,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T13:00:00.000Z',
#   'val_cargaglobal': 19694.953,
#   'val_cargaglobalcons': 19694.953,
#   'val_cargaglobalsmmgd': 17063.088,
#   'val_cargasupervisionada': 15659.863,
#   'val_carganaosupervisionada': 1403.2249,
#   'val_cargammgd': 2631.8655,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T13:30:00.000Z',
#   'val_cargaglobal': 19984.557,
#   'val_cargaglobalcons': 19984.557,
#   'val_cargaglobalsmmgd': 16972.988,
#   'val_cargasupervisionada': 15572.056,
#   'val_carganaosupervisionada': 1400.9335,
#   'val_cargammgd': 3011.569,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T14:00:00.000Z',
#   'val_cargaglobal': 20279.99,
#   'val_cargaglobalcons': 20279.99,
#   'val_cargaglobalsmmgd': 16958.34,
#   'val_cargasupervisionada': 15559.357,
#   'val_carganaosupervisionada': 1398.9819,
#   'val_cargammgd': 3321.651,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T14:30:00.000Z',
#   'val_cargaglobal': 20526.451,
#   'val_cargaglobalcons': 20526.451,
#   'val_cargaglobalsmmgd': 16971.594,
#   'val_cargasupervisionada': 15573.791,
#   'val_carganaosupervisionada': 1397.8022,
#   'val_cargammgd': 3554.8574,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T15:00:00.000Z',
#   'val_cargaglobal': 20559.723,
#   'val_cargaglobalcons': 20559.723,
#   'val_cargaglobalsmmgd': 16882.041,
#   'val_cargasupervisionada': 15484.649,
#   'val_carganaosupervisionada': 1397.3917,
#   'val_cargammgd': 3677.6826,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T15:30:00.000Z',
#   'val_cargaglobal': 20218.541,
#   'val_cargaglobalcons': 20218.541,
#   'val_cargaglobalsmmgd': 16530.877,
#   'val_cargasupervisionada': 15133.53,
#   'val_carganaosupervisionada': 1397.3469,
#   'val_cargammgd': 3687.6638,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T16:00:00.000Z',
#   'val_cargaglobal': 19993.074,
#   'val_cargaglobalcons': 19993.074,
#   'val_cargaglobalsmmgd': 16364.219,
#   'val_cargasupervisionada': 14966.236,
#   'val_carganaosupervisionada': 1397.9825,
#   'val_cargammgd': 3628.8562,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T16:30:00.000Z',
#   'val_cargaglobal': 20337.941,
#   'val_cargaglobalcons': 20337.941,
#   'val_cargaglobalsmmgd': 16837.092,
#   'val_cargasupervisionada': 15439.023,
#   'val_carganaosupervisionada': 1398.0684,
#   'val_cargammgd': 3500.8489,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T17:00:00.000Z',
#   'val_cargaglobal': 20511.086,
#   'val_cargaglobalcons': 20511.086,
#   'val_cargaglobalsmmgd': 17250.975,
#   'val_cargasupervisionada': 15855.588,
#   'val_carganaosupervisionada': 1395.3861,
#   'val_cargammgd': 3260.111,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T17:30:00.000Z',
#   'val_cargaglobal': 20605.102,
#   'val_cargaglobalcons': 20605.102,
#   'val_cargaglobalsmmgd': 17690.623,
#   'val_cargasupervisionada': 16297.473,
#   'val_carganaosupervisionada': 1393.1495,
#   'val_cargammgd': 2914.4795,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T18:00:00.000Z',
#   'val_cargaglobal': 20651.898,
#   'val_cargaglobalcons': 20651.898,
#   'val_cargaglobalsmmgd': 18091.758,
#   'val_cargasupervisionada': 16698.693,
#   'val_carganaosupervisionada': 1393.0652,
#   'val_cargammgd': 2560.1406,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T18:30:00.000Z',
#   'val_cargaglobal': 20685.934,
#   'val_cargaglobalcons': 20685.934,
#   'val_cargaglobalsmmgd': 18484.594,
#   'val_cargasupervisionada': 17091.553,
#   'val_carganaosupervisionada': 1393.0416,
#   'val_cargammgd': 2201.3394,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T19:00:00.000Z',
#   'val_cargaglobal': 20795.459,
#   'val_cargaglobalcons': 20795.459,
#   'val_cargaglobalsmmgd': 19012.598,
#   'val_cargasupervisionada': 17620.424,
#   'val_carganaosupervisionada': 1392.1731,
#   'val_cargammgd': 1782.8607,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T19:30:00.000Z',
#   'val_cargaglobal': 20822.049,
#   'val_cargaglobalcons': 20822.049,
#   'val_cargaglobalsmmgd': 19516.264,
#   'val_cargasupervisionada': 18124.273,
#   'val_carganaosupervisionada': 1391.9908,
#   'val_cargammgd': 1305.7849,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T20:00:00.000Z',
#   'val_cargaglobal': 20882.361,
#   'val_cargaglobalcons': 20882.361,
#   'val_cargaglobalsmmgd': 20043.605,
#   'val_cargasupervisionada': 18649.059,
#   'val_carganaosupervisionada': 1394.546,
#   'val_cargammgd': 838.7551,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T20:30:00.000Z',
#   'val_cargaglobal': 20766.492,
#   'val_cargaglobalcons': 20766.492,
#   'val_cargaglobalsmmgd': 20398.412,
#   'val_cargasupervisionada': 19000.025,
#   'val_carganaosupervisionada': 1398.3861,
#   'val_cargammgd': 368.0801,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T21:00:00.000Z',
#   'val_cargaglobal': 21292.605,
#   'val_cargaglobalcons': 21292.605,
#   'val_cargaglobalsmmgd': 21149.266,
#   'val_cargasupervisionada': 19746.182,
#   'val_carganaosupervisionada': 1403.0836,
#   'val_cargammgd': 143.3399,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T21:30:00.000Z',
#   'val_cargaglobal': 22420.307,
#   'val_cargaglobalcons': 22420.307,
#   'val_cargaglobalsmmgd': 22398.768,
#   'val_cargasupervisionada': 20991.15,
#   'val_carganaosupervisionada': 1407.6165,
#   'val_cargammgd': 21.5396,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T22:00:00.000Z',
#   'val_cargaglobal': 23131.06,
#   'val_cargaglobalcons': 23131.06,
#   'val_cargaglobalsmmgd': 23109.93,
#   'val_cargasupervisionada': 21699.498,
#   'val_carganaosupervisionada': 1410.4325,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T22:30:00.000Z',
#   'val_cargaglobal': 23026.836,
#   'val_cargaglobalcons': 23026.836,
#   'val_cargaglobalsmmgd': 23005.705,
#   'val_cargasupervisionada': 21593.01,
#   'val_carganaosupervisionada': 1412.6948,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T23:00:00.000Z',
#   'val_cargaglobal': 22632.068,
#   'val_cargaglobalcons': 22632.068,
#   'val_cargaglobalsmmgd': 22610.938,
#   'val_cargasupervisionada': 21195.46,
#   'val_carganaosupervisionada': 1415.4773,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-07T23:30:00.000Z',
#   'val_cargaglobal': 22225.947,
#   'val_cargaglobalcons': 22225.947,
#   'val_cargaglobalsmmgd': 22204.816,
#   'val_cargasupervisionada': 20787.322,
#   'val_carganaosupervisionada': 1417.4948,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-08T00:00:00.000Z',
#   'val_cargaglobal': 22076.066,
#   'val_cargaglobalcons': 22076.066,
#   'val_cargaglobalsmmgd': 22054.936,
#   'val_cargasupervisionada': 20638.016,
#   'val_carganaosupervisionada': 1416.9202,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-08T00:30:00.000Z',
#   'val_cargaglobal': 21716.17,
#   'val_cargaglobalcons': 21716.17,
#   'val_cargaglobalsmmgd': 21695.04,
#   'val_cargasupervisionada': 20278.588,
#   'val_carganaosupervisionada': 1416.452,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-08T01:00:00.000Z',
#   'val_cargaglobal': 20930.443,
#   'val_cargaglobalcons': 20930.443,
#   'val_cargaglobalsmmgd': 20909.312,
#   'val_cargasupervisionada': 19490.105,
#   'val_carganaosupervisionada': 1419.2076,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-08T01:30:00.000Z',
#   'val_cargaglobal': 19936.19,
#   'val_cargaglobalcons': 19936.19,
#   'val_cargaglobalsmmgd': 19915.059,
#   'val_cargasupervisionada': 18492.955,
#   'val_carganaosupervisionada': 1422.1025,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-08T02:00:00.000Z',
#   'val_cargaglobal': 19153.877,
#   'val_cargaglobalcons': 19153.877,
#   'val_cargaglobalsmmgd': 19132.746,
#   'val_cargasupervisionada': 17709.488,
#   'val_carganaosupervisionada': 1423.2574,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-08T02:30:00.000Z',
#   'val_cargaglobal': 18149.57,
#   'val_cargaglobalcons': 18149.57,
#   'val_cargaglobalsmmgd': 18128.44,
#   'val_cargasupervisionada': 16700.184,
#   'val_carganaosupervisionada': 1428.2562,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0},
#  {'cod_areacarga': 'SP',
#   'din_atualizacao': '2026-08-14T05:59:18.553Z',
#   'dat_referencia': '2025-08-07',
#   'din_referenciautc': '2025-08-08T03:00:00.000Z',
#   'val_cargaglobal': 17271.514,
#   'val_cargaglobalcons': 17271.514,
#   'val_cargaglobalsmmgd': 17250.383,
#   'val_cargasupervisionada': 15785.905,
#   'val_carganaosupervisionada': 1464.4777,
#   'val_cargammgd': 21.13,
#   'val_consistencia': 0}]

# %% [markdown]
# # A partir daqui, o trabalho é da equipe
#
# ## DESAFIO 1 — Construção e inspeção do DataFrame
#
# 1. Crie um DataFrame Pandas chamado `dados` a partir de `registros`.
# 2. Exiba os primeiros registros.
# 3. Determine a quantidade de linhas e colunas.
# 4. Liste os nomes dos atributos.
# 5. Utilize `info()`.
# 6. Utilize `describe()`.
# 7. Em Markdown, identifique quais atributos representam data/hora, área de carga e valor de carga.
#
# **Antes de prosseguir, compreenda a estrutura efetivamente retornada pela API.**

# %%
# DESAFIO 1 — Construção e inspeção do DataFrame

# 1. Criar o DataFrame Pandas a partir de `registros`.
dados = pd.DataFrame(registros)

# 2. Exibir os primeiros registros.
print("# DESAFIO 1.2 — Primeiros registros")
display(dados.head())

# 3. Determinar a quantidade de linhas e colunas.
print("# DESAFIO 1.3 — Quantidade de linhas e colunas")
print("Linhas:", dados.shape[0])
print("Colunas:", dados.shape[1])

# 4. Listar os nomes dos atributos.
print("# DESAFIO 1.4 — Nomes dos atributos")
print(dados.columns.tolist())

# 5. Utilizar info().
print("# DESAFIO 1.5 — Informações do DataFrame")
dados.info()

# 6. Utilizar describe().
print("# DESAFIO 1.6 — Estatísticas descritivas")
display(dados.describe(include="all").T)

# 7. Identificação dos atributos solicitados.
# Na API atual de Carga Verificada do ONS, os campos relevantes são:
# cod_areacarga      -> código da área de carga
# din_referenciautc  -> data/hora de referência do final do intervalo
# val_cargaglobal    -> valor da carga global em MWmed
# Fonte: Dicionário de Dados — Carga Verificada (ONS).
col_area = "cod_areacarga"
col_data = "din_referenciautc"
col_carga = "val_cargaglobal"

campos_esperados = [col_area, col_data, col_carga]
campos_faltantes = [c for c in campos_esperados if c not in dados.columns]
if campos_faltantes:
    raise KeyError(
        "A resposta da API não contém os campos esperados: "
        + ", ".join(campos_faltantes)
        + ". Colunas recebidas: " + ", ".join(map(str, dados.columns))
    )

print("# DESAFIO 1.7 — Identificação dos atributos")
print(f"Data/hora: {col_data}")
print(f"Área de carga: {col_area}")
print(f"Valor de carga: {col_carga}")
# Out:
# # DESAFIO 1.2 — Primeiros registros
#   cod_areacarga           din_atualizacao dat_referencia  \
# 0            SP  2026-08-14T05:58:29.574Z     2025-08-01
# 1            SP  2026-08-14T05:58:29.574Z     2025-08-01
# 2            SP  2026-08-14T05:58:29.574Z     2025-08-01
# 3            SP  2026-08-14T05:58:29.574Z     2025-08-01
# 4            SP  2026-08-14T05:58:29.574Z     2025-08-01
#
#           din_referenciautc  val_cargaglobal  val_cargaglobalcons  \
# 0  2025-08-01T03:30:00.000Z        15913.618            15913.618
# 1  2025-08-01T04:00:00.000Z        15251.414            15251.414
# 2  2025-08-01T04:30:00.000Z        14606.733            14606.733
# 3  2025-08-01T05:00:00.000Z        14182.290            14182.290
# 4  2025-08-01T05:30:00.000Z        13838.488            13838.488
#
#    val_cargaglobalsmmgd  val_cargasupervisionada  val_carganaosupervisionada  \
# 0             15892.488                14421.112                   1471.3759
# 1             15230.284                13758.101                   1472.1840
# 2             14585.604                13112.602                   1473.0022
# 3             14161.160                12687.433                   1473.7275
# 4             13817.358                12342.648                   1474.7096
#
#    val_cargammgd  val_consistencia
# 0          21.13                 0
# 1          21.13                 0
# 2          21.13                 0
# 3          21.13                 0
# 4          21.13                 0
# # DESAFIO 1.3 — Quantidade de linhas e colunas
# Linhas: 336
# Colunas: 11
# # DESAFIO 1.4 — Nomes dos atributos
# ['cod_areacarga', 'din_atualizacao', 'dat_referencia', 'din_referenciautc', 'val_cargaglobal', 'val_cargaglobalcons', 'val_cargaglobalsmmgd', 'val_cargasupervisionada', 'val_carganaosupervisionada', 'val_cargammgd', 'val_consistencia']
# # DESAFIO 1.5 — Informações do DataFrame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cod_areacarga               336 non-null    object
#  1   din_atualizacao             336 non-null    object
#  2   dat_referencia              336 non-null    object
#  3   din_referenciautc           336 non-null    object
#  4   val_cargaglobal             336 non-null    float64
#  5   val_cargaglobalcons         336 non-null    float64
#  6   val_cargaglobalsmmgd        336 non-null    float64
#  7   val_cargasupervisionada     336 non-null    float64
#  8   val_carganaosupervisionada  336 non-null    float64
#  9   val_cargammgd               336 non-null    float64
#  10  val_consistencia            336 non-null    int64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 29.0+ KB
# # DESAFIO 1.6 — Estatísticas descritivas
#                             count unique                       top freq  \
# cod_areacarga                 336      1                        SP  336
# din_atualizacao               336      7  2026-08-14T05:58:29.574Z   48
# dat_referencia                336      7                2025-08-01   48
# din_referenciautc             336    336  2025-08-07T19:00:00.000Z    1
# val_cargaglobal             336.0    NaN                       NaN  NaN
# val_cargaglobalcons         336.0    NaN                       NaN  NaN
# val_cargaglobalsmmgd        336.0    NaN                       NaN  NaN
# val_cargasupervisionada     336.0    NaN                       NaN  NaN
# val_carganaosupervisionada  336.0    NaN                       NaN  NaN
# val_cargammgd               336.0    NaN                       NaN  NaN
# val_consistencia            336.0    NaN                       NaN  NaN
#
#                                     mean          std        min  \
# cod_areacarga                        NaN          NaN        NaN
# din_atualizacao                      NaN          NaN        NaN
# dat_referencia                       NaN          NaN        NaN
# din_referenciautc                    NaN          NaN        NaN
# val_cargaglobal             17870.828981  3029.042438  12139.253
# val_cargaglobalcons         17870.828981  3029.042438  12139.253
# val_cargaglobalsmmgd        16953.421626  2962.721503  11549.664
# val_cargasupervisionada     15495.799695  2982.650359  10054.455
# val_carganaosupervisionada   1457.621862    34.888571  1391.9908
# val_cargammgd                 917.407249  1253.581141      21.13
# val_consistencia                     0.0          0.0        0.0
#
#                                      25%         50%          75%        max
# cod_areacarga                        NaN         NaN          NaN        NaN
# din_atualizacao                      NaN         NaN          NaN        NaN
# dat_referencia                       NaN         NaN          NaN        NaN
# din_referenciautc                    NaN         NaN          NaN        NaN
# val_cargaglobal             15110.533375  18199.1285   20386.6295  23185.312
# val_cargaglobalcons         15110.533375  18199.1285   20386.6295  23185.312
# val_cargaglobalsmmgd         14457.60425    17045.26   18931.6795  23164.182
# val_cargasupervisionada       12990.8785  15611.6295   17502.6435  21717.934
# val_carganaosupervisionada   1433.112575  1453.98165  1479.430775  1538.2747
# val_cargammgd                      21.13     21.1969  1793.579475  3736.0098
# val_consistencia                     0.0         0.0          0.0        0.0
# # DESAFIO 1.7 — Identificação dos atributos
# Data/hora: din_referenciautc
# Área de carga: cod_areacarga
# Valor de carga: val_cargaglobal

# %% [markdown]
# ## DESAFIO 1 — Identificação dos atributos
#
# **# DESAFIO 1.7 — Resposta**
#
# Na resposta da API de **Carga Verificada do ONS**, os atributos utilizados nesta análise são:
#
# - **Data/hora:** `din_referenciautc`, que representa a data/hora de referência do final do intervalo da medição.
# - **Área de carga:** `cod_areacarga`, que identifica a área de carga consultada; neste trabalho, o código utilizado na consulta é `SP`.
# - **Valor de carga:** `val_cargaglobal`, que representa o valor da carga global em MWmed.
#
# Esses campos correspondem ao dicionário oficial da API de Carga Verificada do ONS.

# %%
# DESAFIO 2 — Organização dos dados

# Os campos foram identificados no DESAFIO 1 de acordo com a estrutura atual da API.

# 1. Renomear os principais atributos com nomes mais simples.
mapa_nomes = {
    col_data: "data_hora",
    col_area: "area",
    col_carga: "carga"
}

dados_organizados = dados.rename(columns=mapa_nomes).copy()

# 2. Criar um novo DataFrame contendo apenas os atributos necessários.
dados_analise = dados_organizados[["data_hora", "area", "carga"]].copy()

# 3. Verificar valores ausentes.
print("# DESAFIO 2.3 — Valores ausentes")
display(dados_analise.isna().sum().to_frame("quantidade_ausentes"))

# 4. Informar quantos valores ausentes existem em cada atributo relevante.
print("# DESAFIO 2.4 — Valores ausentes por atributo relevante")
for coluna in dados_analise.columns:
    print(f"{coluna}: {dados_analise[coluna].isna().sum()}")

# 5. Verificar se a variável de carga está em formato numérico.
print("# DESAFIO 2.5 — Tipo da variável de carga")
print("Tipo original:", dados_analise["carga"].dtype)
dados_analise["carga"] = pd.to_numeric(dados_analise["carga"], errors="coerce")
print("Tipo após conversão segura:", dados_analise["carga"].dtype)

# 6. Verificar como a data/hora está representada.
print("# DESAFIO 2.6 — Representação da data/hora")
print("Tipo original:", dados_analise["data_hora"].dtype)
dados_analise["data_hora"] = pd.to_datetime(dados_analise["data_hora"], errors="coerce", utc=True)
print("Tipo após conversão:", dados_analise["data_hora"].dtype)

# 7. Decisão de tratamento.
antes = len(dados_analise)
dados_analise = dados_analise.dropna(subset=["data_hora", "area", "carga"]).copy()
depois = len(dados_analise)

print("# DESAFIO 2.7 — Decisão de tratamento")
print(f"Foram removidas {antes - depois} linhas com ausência ou valor não conversível em data/hora, área ou carga.")
print("Nenhum valor de carga foi imputado; apenas registros sem os campos essenciais foram descartados.")

display(dados_analise.head())
# Out:
# # DESAFIO 2.3 — Valores ausentes
#            quantidade_ausentes
# data_hora                    0
# area                         0
# carga                        0
# # DESAFIO 2.4 — Valores ausentes por atributo relevante
# data_hora: 0
# area: 0
# carga: 0
# # DESAFIO 2.5 — Tipo da variável de carga
# Tipo original: float64
# Tipo após conversão segura: float64
# # DESAFIO 2.6 — Representação da data/hora
# Tipo original: object
# Tipo após conversão: datetime64[ns, UTC]
# # DESAFIO 2.7 — Decisão de tratamento
# Foram removidas 0 linhas com ausência ou valor não conversível em data/hora, área ou carga.
# Nenhum valor de carga foi imputado; apenas registros sem os campos essenciais foram descartados.
#                   data_hora area      carga
# 0 2025-08-01 03:30:00+00:00   SP  15913.618
# 1 2025-08-01 04:00:00+00:00   SP  15251.414
# 2 2025-08-01 04:30:00+00:00   SP  14606.733
# 3 2025-08-01 05:00:00+00:00   SP  14182.290
# 4 2025-08-01 05:30:00+00:00   SP  13838.488

# %% [markdown]
# ## DESAFIO 2 — Decisão de tratamento
#
# **# DESAFIO 2.7 — Resposta**
#
# Os três atributos principais foram renomeados para `data_hora`, `area` e `carga`, e foi criado o DataFrame `dados_analise` contendo somente esses campos.
#
# A variável `carga` foi convertida para formato numérico e `data_hora` para `datetime` com informação de UTC. Registros que ficaram sem data/hora, área ou carga após a conversão foram removidos. Não foi realizada imputação de valores, evitando criar informações que não estejam presentes nos dados da API.

# %%
# DESAFIO 3 — Indicadores da carga elétrica

# Garantir ordenação temporal para as análises seguintes.
dados_analise = dados_analise.sort_values("data_hora").reset_index(drop=True)

# 1. Carga mínima.
carga_minima = dados_analise["carga"].min()

# 2. Carga máxima.
carga_maxima = dados_analise["carga"].max()

# 3. Carga média.
carga_media = dados_analise["carga"].mean()

# 4. Mediana.
mediana_carga = dados_analise["carga"].median()

# 5. Amplitude entre máximo e mínimo.
amplitude_carga = carga_maxima - carga_minima

# 6. Quantidade total de medições.
quantidade_medicoes = len(dados_analise)

indicadores = pd.DataFrame({
    "Indicador": [
        "Carga mínima", "Carga máxima", "Carga média",
        "Mediana", "Amplitude", "Quantidade total de medições"
    ],
    "Valor": [
        carga_minima, carga_maxima, carga_media,
        mediana_carga, amplitude_carga, quantidade_medicoes
    ]
})

print("# DESAFIO 3 — Indicadores calculados")
display(indicadores)

# Resposta à pergunta do desafio.
distancia_max_media = carga_maxima - carga_media
razao_max_media = carga_maxima / carga_media if carga_media else float("nan")

print("# DESAFIO 3 — Resposta")
print(
    f"O valor máximo foi {distancia_max_media:.2f} acima da média, "
    f"correspondendo a aproximadamente {razao_max_media:.2f} vezes a média."
)
print(
    "Assim, a distância entre máximo e média deve ser avaliada em conjunto com a mediana "
    "e a amplitude; os indicadores acima mostram objetivamente o quanto o pico se afasta "
    "do comportamento central observado."
)
# Out:
# # DESAFIO 3 — Indicadores calculados
#                       Indicador         Valor
# 0                  Carga mínima  12139.253000
# 1                  Carga máxima  23185.312000
# 2                   Carga média  17870.828981
# 3                       Mediana  18199.128500
# 4                     Amplitude  11046.059000
# 5  Quantidade total de medições    336.000000
# # DESAFIO 3 — Resposta
# O valor máximo foi 5314.48 acima da média, correspondendo a aproximadamente 1.30 vezes a média.
# Assim, a distância entre máximo e média deve ser avaliada em conjunto com a mediana e a amplitude; os indicadores acima mostram objetivamente o quanto o pico se afasta do comportamento central observado.

# %% [markdown]
# ## DESAFIO 4 — Períodos de alta demanda
#
# Considere como **alta demanda** os registros com carga superior a **90% da carga máxima**.
#
# 1. Calcule o limiar.
# 2. Crie um novo DataFrame com os registros acima dele.
# 3. Conte os registros.
# 4. Calcule o percentual em relação ao total.
# 5. Identifique o maior valor de carga.
# 6. Identifique a data e o horário do pico, quando disponíveis.
#
# Responda:
#
# **Os períodos próximos ao pico representam uma parcela grande ou pequena do período analisado?**

# %%
# DESAFIO 4 — Períodos de alta demanda

# 1. Calcular o limiar de alta demanda: 90% da carga máxima.
limiar_alta_demanda = 0.90 * carga_maxima

# 2. Criar DataFrame com registros acima do limiar.
alta_demanda = dados_analise[dados_analise["carga"] > limiar_alta_demanda].copy()

# 3. Contar registros.
quantidade_alta_demanda = len(alta_demanda)

# 4. Calcular percentual em relação ao total.
percentual_alta_demanda = (
    quantidade_alta_demanda / quantidade_medicoes * 100
    if quantidade_medicoes else 0
)

# 5. Identificar o maior valor de carga.
pico = dados_analise.loc[dados_analise["carga"].idxmax()]

# 6. Identificar data e horário do pico.
momento_pico = pico["data_hora"]

print("# DESAFIO 4.1 — Limiar")
print(f"Limiar de alta demanda (90% do máximo): {limiar_alta_demanda:.2f}")

print("# DESAFIO 4.2 — DataFrame de alta demanda")
display(alta_demanda)

print("# DESAFIO 4.3 e 4.4 — Quantidade e percentual")
print("Registros de alta demanda:", quantidade_alta_demanda)
print(f"Percentual do período: {percentual_alta_demanda:.2f}%")

print("# DESAFIO 4.5 e 4.6 — Pico")
print(f"Maior carga: {carga_maxima:.2f}")
print(f"Momento do pico: {momento_pico}")

print("# DESAFIO 4 — Resposta")
if percentual_alta_demanda < 10:
    interpretacao_alta = "uma parcela pequena"
elif percentual_alta_demanda < 30:
    interpretacao_alta = "uma parcela moderada"
else:
    interpretacao_alta = "uma parcela grande"

print(
    f"Os períodos próximos ao pico representam {interpretacao_alta} do período analisado, "
    f"pois {quantidade_alta_demanda} de {quantidade_medicoes} medições "
    f"({percentual_alta_demanda:.2f}%) ficaram acima de 90% da carga máxima."
)
# Out:
# # DESAFIO 4.1 — Limiar
# Limiar de alta demanda (90% do máximo): 20866.78
# # DESAFIO 4.2 — DataFrame de alta demanda
#                     data_hora area      carga
# 35  2025-08-01 21:00:00+00:00   SP  21088.959
# 36  2025-08-01 21:30:00+00:00   SP  22398.360
# 37  2025-08-01 22:00:00+00:00   SP  23185.312
# 38  2025-08-01 22:30:00+00:00   SP  22903.314
# 39  2025-08-01 23:00:00+00:00   SP  22358.701
# 40  2025-08-01 23:30:00+00:00   SP  21697.979
# 41  2025-08-02 00:00:00+00:00   SP  21385.326
# 42  2025-08-02 00:30:00+00:00   SP  20919.314
# 84  2025-08-02 21:30:00+00:00   SP  20983.484
# 85  2025-08-02 22:00:00+00:00   SP  21202.566
# 167 2025-08-04 15:00:00+00:00   SP  20903.652
# 171 2025-08-04 17:00:00+00:00   SP  20983.945
# 172 2025-08-04 17:30:00+00:00   SP  21058.111
# 173 2025-08-04 18:00:00+00:00   SP  20957.283
# 179 2025-08-04 21:00:00+00:00   SP  21151.498
# 180 2025-08-04 21:30:00+00:00   SP  22124.520
# 181 2025-08-04 22:00:00+00:00   SP  22691.178
# 182 2025-08-04 22:30:00+00:00   SP  22602.280
# 183 2025-08-04 23:00:00+00:00   SP  22387.479
# 184 2025-08-04 23:30:00+00:00   SP  21873.928
# 185 2025-08-05 00:00:00+00:00   SP  21625.650
# 186 2025-08-05 00:30:00+00:00   SP  21180.598
# 214 2025-08-05 14:30:00+00:00   SP  20950.814
# 215 2025-08-05 15:00:00+00:00   SP  20988.578
# 227 2025-08-05 21:00:00+00:00   SP  21427.500
# 228 2025-08-05 21:30:00+00:00   SP  22441.875
# 229 2025-08-05 22:00:00+00:00   SP  23142.227
# 230 2025-08-05 22:30:00+00:00   SP  23019.832
# 231 2025-08-05 23:00:00+00:00   SP  22625.648
# 232 2025-08-05 23:30:00+00:00   SP  22089.646
# 233 2025-08-06 00:00:00+00:00   SP  21937.125
# 234 2025-08-06 00:30:00+00:00   SP  21502.771
# 275 2025-08-06 21:00:00+00:00   SP  21192.049
# 276 2025-08-06 21:30:00+00:00   SP  22320.617
# 277 2025-08-06 22:00:00+00:00   SP  23149.518
# 278 2025-08-06 22:30:00+00:00   SP  22975.998
# 279 2025-08-06 23:00:00+00:00   SP  22521.299
# 280 2025-08-06 23:30:00+00:00   SP  22248.188
# 281 2025-08-07 00:00:00+00:00   SP  21846.860
# 282 2025-08-07 00:30:00+00:00   SP  21264.129
# 321 2025-08-07 20:00:00+00:00   SP  20882.361
# 323 2025-08-07 21:00:00+00:00   SP  21292.605
# 324 2025-08-07 21:30:00+00:00   SP  22420.307
# 325 2025-08-07 22:00:00+00:00   SP  23131.060
# 326 2025-08-07 22:30:00+00:00   SP  23026.836
# 327 2025-08-07 23:00:00+00:00   SP  22632.068
# 328 2025-08-07 23:30:00+00:00   SP  22225.947
# 329 2025-08-08 00:00:00+00:00   SP  22076.066
# 330 2025-08-08 00:30:00+00:00   SP  21716.170
# 331 2025-08-08 01:00:00+00:00   SP  20930.443
# # DESAFIO 4.3 e 4.4 — Quantidade e percentual
# Registros de alta demanda: 50
# Percentual do período: 14.88%
# # DESAFIO 4.5 e 4.6 — Pico
# Maior carga: 23185.31
# Momento do pico: 2025-08-01 22:00:00+00:00
# # DESAFIO 4 — Resposta
# Os períodos próximos ao pico representam uma parcela moderada do período analisado, pois 50 de 336 medições (14.88%) ficaram acima de 90% da carga máxima.

# %% [markdown]
# ## DESAFIO 4 — Interpretação
#
# **# DESAFIO 4 — Resposta**
#
# Foi considerado como alta demanda todo registro superior a 90% da carga máxima. A quantidade e o percentual encontrados são calculados diretamente na célula anterior.
#
# A conclusão é baseada somente na proporção das medições que ultrapassaram o limiar, sem atribuir uma causa externa ao comportamento observado.

# %%
# DESAFIO 5 — Segundo critério de análise

# 1. Critério escolhido:
# carga acima da média observada no período.
criterio_segundo = "Carga acima da média"

segundo_criterio = dados_analise[dados_analise["carga"] > carga_media].copy()

# 3. Quantidade de registros.
quantidade_segundo = len(segundo_criterio)

# 4. Percentual.
percentual_segundo = (
    quantidade_segundo / quantidade_medicoes * 100
    if quantidade_medicoes else 0
)

# 5. Comparação com o conjunto de alta demanda.
comparacao = pd.DataFrame({
    "Critério": ["Alta demanda (>90% do máximo)", "Segundo critério (> média)"],
    "Quantidade": [quantidade_alta_demanda, quantidade_segundo],
    "Percentual (%)": [percentual_alta_demanda, percentual_segundo]
})

print("# DESAFIO 5.1 — Critério escolhido")
print(criterio_segundo)

print("# DESAFIO 5.2 — Novo DataFrame")
display(segundo_criterio)

print("# DESAFIO 5.3 e 5.4 — Quantidade e percentual")
print("Quantidade:", quantidade_segundo)
print(f"Percentual: {percentual_segundo:.2f}%")

print("# DESAFIO 5.5 — Comparação com alta demanda")
display(comparacao)

print("# DESAFIO 5 — Interpretação")
print(
    f"O critério de alta demanda selecionou {percentual_alta_demanda:.2f}% das medições, "
    f"enquanto o critério de carga acima da média selecionou {percentual_segundo:.2f}%. "
    "Como o segundo critério é menos restritivo, ele tende a abranger mais observações."
)
# Out:
# # DESAFIO 5.1 — Critério escolhido
# Carga acima da média
# # DESAFIO 5.2 — Novo DataFrame
#                     data_hora area      carga
# 15  2025-08-01 11:00:00+00:00   SP  18096.023
# 16  2025-08-01 11:30:00+00:00   SP  18629.395
# 17  2025-08-01 12:00:00+00:00   SP  18825.176
# 18  2025-08-01 12:30:00+00:00   SP  19056.504
# 19  2025-08-01 13:00:00+00:00   SP  19427.822
# ..                        ...  ...        ...
# 330 2025-08-08 00:30:00+00:00   SP  21716.170
# 331 2025-08-08 01:00:00+00:00   SP  20930.443
# 332 2025-08-08 01:30:00+00:00   SP  19936.190
# 333 2025-08-08 02:00:00+00:00   SP  19153.877
# 334 2025-08-08 02:30:00+00:00   SP  18149.570
#
# [184 rows x 3 columns]
# # DESAFIO 5.3 e 5.4 — Quantidade e percentual
# Quantidade: 184
# Percentual: 54.76%
# # DESAFIO 5.5 — Comparação com alta demanda
#                         Critério  Quantidade  Percentual (%)
# 0  Alta demanda (>90% do máximo)          50       14.880952
# 1     Segundo critério (> média)         184       54.761905
# # DESAFIO 5 — Interpretação
# O critério de alta demanda selecionou 14.88% das medições, enquanto o critério de carga acima da média selecionou 54.76%. Como o segundo critério é menos restritivo, ele tende a abranger mais observações.

# %% [markdown]
# ## DESAFIO 5 — Critério e comparação
#
# **# DESAFIO 5.1 — Critério escolhido:** carga acima da média do período.
#
# Esse critério foi escolhido por permitir identificar todas as observações que ficaram acima do comportamento central calculado para o conjunto.
#
# **# DESAFIO 5.5 — Comparação:** a célula anterior apresenta lado a lado a quantidade e o percentual do segundo critério e do critério de alta demanda (>90% do máximo).

# %%
# DESAFIO 6 — Visualização

# 1. Gráfico do comportamento da carga ao longo do tempo.
plt.figure(figsize=(12, 5))
plt.plot(dados_analise["data_hora"], dados_analise["carga"])
plt.title("Carga elétrica ao longo do período — São Paulo")
plt.xlabel("Data e hora")
plt.ylabel("Carga")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print("# DESAFIO 6.1 — Interpretação")
print(
    "O gráfico apresenta a variação da carga ao longo das observações do período. "
    "Os maiores valores podem ser comparados visualmente com a média e com o pico calculados."
)

# 2. Segundo gráfico: distribuição das cargas.
plt.figure(figsize=(8, 5))
plt.hist(dados_analise["carga"], bins=20)
plt.axvline(carga_media, linestyle="--", label=f"Média: {carga_media:.2f}")
plt.axvline(limiar_alta_demanda, linestyle="--", label=f"90% do máximo: {limiar_alta_demanda:.2f}")
plt.title("Distribuição das cargas observadas")
plt.xlabel("Carga")
plt.ylabel("Quantidade de medições")
plt.legend()
plt.tight_layout()
plt.show()

print("# DESAFIO 6.2 — Interpretação")
print(
    "O histograma mostra como as medições estão distribuídas. "
    "A linha da média permite localizar o comportamento central e a linha de 90% do máximo "
    "permite visualizar a faixa definida como alta demanda."
)
# Out:
# # DESAFIO 6.1 — Interpretação
# O gráfico apresenta a variação da carga ao longo das observações do período. Os maiores valores podem ser comparados visualmente com a média e com o pico calculados.
# # DESAFIO 6.2 — Interpretação
# O histograma mostra como as medições estão distribuídas. A linha da média permite localizar o comportamento central e a linha de 90% do máximo permite visualizar a faixa definida como alta demanda.

# %% [markdown]
# ## DESAFIO 6 — Interpretações dos gráficos
#
# **# DESAFIO 6 — Gráfico 1:** a série temporal permite observar diretamente como a carga variou durante o período analisado e localizar visualmente os maiores picos.
#
# **# DESAFIO 6 — Gráfico 2:** o histograma mostra a distribuição das medições e permite comparar a concentração dos valores com a média e com o limiar de alta demanda.
#
# As interpretações não atribuem causas às variações, pois essas causas não podem ser determinadas somente pelos dados analisados.

# %%
# DESAFIO 7 — Síntese para o relatório

inicio_periodo = dados_analise["data_hora"].min()
fim_periodo = dados_analise["data_hora"].max()

resumo_resultados = f"""
Região analisada: São Paulo (SP)
Período analisado: {inicio_periodo} a {fim_periodo}
Quantidade de registros: {quantidade_medicoes}
Carga mínima: {carga_minima:.2f}
Carga máxima: {carga_maxima:.2f}
Carga média: {carga_media:.2f}
Mediana: {mediana_carga:.2f}
Amplitude: {amplitude_carga:.2f}
Limiar de alta demanda (90% do máximo): {limiar_alta_demanda:.2f}
Registros de alta demanda: {quantidade_alta_demanda}
Percentual de alta demanda: {percentual_alta_demanda:.2f}%
Momento do pico: {momento_pico}
Segundo critério: {criterio_segundo}
Registros acima da média: {quantidade_segundo}
Percentual acima da média: {percentual_segundo:.2f}%
"""

print("# DESAFIO 7 — resumo_resultados")
print(resumo_resultados)
# Out:
# # DESAFIO 7 — resumo_resultados
#
# Região analisada: São Paulo (SP)
# Período analisado: 2025-08-01 03:30:00+00:00 a 2025-08-08 03:00:00+00:00
# Quantidade de registros: 336
# Carga mínima: 12139.25
# Carga máxima: 23185.31
# Carga média: 17870.83
# Mediana: 18199.13
# Amplitude: 11046.06
# Limiar de alta demanda (90% do máximo): 20866.78
# Registros de alta demanda: 50
# Percentual de alta demanda: 14.88%
# Momento do pico: 2025-08-01 22:00:00+00:00
# Segundo critério: Carga acima da média
# Registros acima da média: 184
# Percentual acima da média: 54.76%

# %% [markdown]
# ## OPCIONAL: Relatório técnico com apoio do Gemini
#
# **# Conforme solicitado, a geração do relatório pelo Gemini foi ignorada.**
#
# O relatório técnico foi elaborado diretamente a partir dos resultados calculados pela equipe e inserido na seção **Relatório final**, sem uso de geração automática por IA.

# %%
# # DESAFIO 8 — Geração por Gemini: ignorada conforme solicitado.

# %%
# # DESAFIO 8 — Geração por Gemini: ignorada conforme solicitado.

# %% [markdown]
# ## DESAFIO 8 — Geração do relatório
#
# O relatório deve:
#
# - usar os resultados calculados;
# - apresentar os principais indicadores;
# - destacar o pico e os períodos de alta demanda;
# - comparar os dois critérios;
# - não inventar causas;
# - diferenciar observações de hipóteses;
# - terminar com uma conclusão.

# %%
# DESAFIO 8 — Relatório técnico sem Gemini

# O relatório final abaixo é construído exclusivamente com os resultados
# produzidos nas etapas anteriores. Nenhuma causa externa é inventada.
relatorio_final = f"""
RELATÓRIO TÉCNICO — ANÁLISE DA CARGA ELÉTRICA DE SÃO PAULO

1. Caracterização do conjunto analisado
Foi analisada a carga elétrica da área de carga de São Paulo (SP), utilizando os
dados de Carga Verificada do ONS para o período de {inicio_periodo} a {fim_periodo}.
O conjunto válido possui {quantidade_medicoes} medições.

2. Principais indicadores
A carga mínima observada foi de {carga_minima:.2f}, enquanto a carga máxima foi de
{carga_maxima:.2f}. A carga média foi de {carga_media:.2f} e a mediana foi de
{mediana_carga:.2f}. A amplitude entre o menor e o maior valor foi de
{amplitude_carga:.2f}.

O valor máximo ficou {distancia_max_media:.2f} acima da média. Portanto, os
indicadores mostram a distância do pico em relação ao comportamento médio, sem
atribuir uma causa para essa diferença.

3. Períodos de alta demanda
Foi definido como alta demanda todo registro superior a 90% da carga máxima.
O limiar calculado foi de {limiar_alta_demanda:.2f}. Foram identificadas
{quantidade_alta_demanda} medições nessa condição, correspondentes a
{percentual_alta_demanda:.2f}% do total.

O maior valor registrado foi de {carga_maxima:.2f}, com ocorrência em
{momento_pico}.

4. Comparação com o segundo critério
O segundo critério adotado foi carga acima da média. Esse recorte reuniu
{quantidade_segundo} medições, equivalentes a {percentual_segundo:.2f}% do total.
Em comparação, o critério de alta demanda selecionou {quantidade_alta_demanda}
medições ({percentual_alta_demanda:.2f}%).

Assim, o critério acima da média abrangeu uma parcela maior do conjunto do que o
critério de alta demanda, pois este último exige proximidade do valor máximo.

5. Conclusão
Os dados analisados mostram a variação da carga elétrica de São Paulo durante o
período estudado. O pico foi identificado objetivamente a partir do maior valor
de carga, e os períodos de alta demanda foram definidos pelo limite de 90% desse
máximo. O segundo recorte, baseado na média, permitiu uma visão mais abrangente
das observações acima do comportamento central.

As conclusões apresentadas são descritivas e baseadas exclusivamente nos dados
obtidos e nos indicadores calculados. Não é possível determinar, a partir deste
conjunto de dados isoladamente, as causas das variações observadas.
"""

print(relatorio_final)
# Out:
# RELATÓRIO TÉCNICO — ANÁLISE DA CARGA ELÉTRICA DE SÃO PAULO
#
# 1. Caracterização do conjunto analisado
# Foi analisada a carga elétrica da área de carga de São Paulo (SP), utilizando os
# dados de Carga Verificada do ONS para o período de 2025-08-01 03:30:00+00:00 a 2025-08-08 03:00:00+00:00.
# O conjunto válido possui 336 medições.
#
# 2. Principais indicadores
# A carga mínima observada foi de 12139.25, enquanto a carga máxima foi de
# 23185.31. A carga média foi de 17870.83 e a mediana foi de
# 18199.13. A amplitude entre o menor e o maior valor foi de
# 11046.06.
#
# O valor máximo ficou 5314.48 acima da média. Portanto, os
# indicadores mostram a distância do pico em relação ao comportamento médio, sem
# atribuir uma causa para essa diferença.
#
# 3. Períodos de alta demanda
# Foi definido como alta demanda todo registro superior a 90% da carga máxima.
# O limiar calculado foi de 20866.78. Foram identificadas
# 50 medições nessa condição, correspondentes a
# 14.88% do total.
#
# O maior valor registrado foi de 23185.31, com ocorrência em
# 2025-08-01 22:00:00+00:00.
#
# 4. Comparação com o segundo critério
# O segundo critério adotado foi carga acima da média. Esse recorte reuniu
# 184 medições, equivalentes a 54.76% do total.
# Em comparação, o critério de alta demanda selecionou 50
# medições (14.88%).
#
# Assim, o critério acima da média abrangeu uma parcela maior do conjunto do que o
# critério de alta demanda, pois este último exige proximidade do valor máximo.
#
# 5. Conclusão
# Os dados analisados mostram a variação da carga elétrica de São Paulo durante o
# período estudado. O pico foi identificado objetivamente a partir do maior valor
# de carga, e os períodos de alta demanda foram definidos pelo limite de 90% desse
# máximo. O segundo recorte, baseado na média, permitiu uma visão mais abrangente
# das observações acima do comportamento central.
#
# As conclusões apresentadas são descritivas e baseadas exclusivamente nos dados
# obtidos e nos indicadores calculados. Não é possível determinar, a partir deste
# conjunto de dados isoladamente, as causas das variações observadas.

# %%
# DESAFIO 9 — Validação crítica

# 1. Os indicadores foram utilizados corretamente?
print("# DESAFIO 9.1")
print(
    "Sim. O relatório utiliza diretamente mínimo, máximo, média, mediana, amplitude, "
    "quantidade de medições, limiar de 90%, quantidade/percentual de alta demanda e "
    "o resultado do segundo critério."
)

# 2. Há alguma afirmação que não pode ser confirmada pelos dados?
print("\n# DESAFIO 9.2")
print(
    "Não foram incluídas causas externas ou explicações que não possam ser verificadas "
    "pelos dados. O relatório se limita a descrever os valores e comparações calculadas."
)

# 3. Houve interpretação exagerada ou causalidade não demonstrada?
print("\n# DESAFIO 9.3")
print(
    "Não. A interpretação foi mantida descritiva. O relatório não afirma que temperatura, "
    "atividade econômica, horário comercial ou qualquer outro fator causou as variações."
)

# 4. Que alterações a equipe realizou no texto?
print("\n# DESAFIO 9.4")
print(
    "Como a geração pelo Gemini foi ignorada, não houve revisão de um texto gerado pela IA. "
    "O relatório foi escrito diretamente com base nos resultados calculados no notebook, "
    "mantendo apenas conclusões sustentadas pelos dados."
)
# Out:
# # DESAFIO 9.1
# Sim. O relatório utiliza diretamente mínimo, máximo, média, mediana, amplitude, quantidade de medições, limiar de 90%, quantidade/percentual de alta demanda e o resultado do segundo critério.
#
# # DESAFIO 9.2
# Não foram incluídas causas externas ou explicações que não possam ser verificadas pelos dados. O relatório se limita a descrever os valores e comparações calculadas.
#
# # DESAFIO 9.3
# Não. A interpretação foi mantida descritiva. O relatório não afirma que temperatura, atividade econômica, horário comercial ou qualquer outro fator causou as variações.
#
# # DESAFIO 9.4
# Como a geração pelo Gemini foi ignorada, não houve revisão de um texto gerado pela IA. O relatório foi escrito diretamente com base nos resultados calculados no notebook, mantendo apenas conclusões sustentadas pelos dados.

# %% [markdown]
# ## DESAFIO 9 — Validação crítica
#
# **# DESAFIO 9.1 — Indicadores:** foram utilizados diretamente os indicadores calculados no notebook.
#
# **# DESAFIO 9.2 — Afirmações não confirmadas:** não foram incluídas causas ou explicações externas que não possam ser demonstradas pelos dados.
#
# **# DESAFIO 9.3 — Exagero/causalidade:** a análise foi mantida descritiva, sem atribuir causas às variações.
#
# **# DESAFIO 9.4 — Alterações realizadas:** conforme solicitado, o Gemini não foi utilizado; portanto, o relatório final foi escrito diretamente a partir dos resultados calculados.

# %% [markdown]
# # RELATÓRIO FINAL
#
# **# DESAFIO 8 — Relatório técnico final**
#
# O relatório final abaixo é construído diretamente a partir dos resultados calculados nas etapas anteriores, conforme solicitado. A geração automática do relatório pelo Gemini foi ignorada.
#
# A análise utiliza a área de carga **SP — São Paulo**, consultada na API de Carga Verificada do ONS para o período definido no notebook.

# %%
# # RELATÓRIO FINAL — versão completa
from IPython.display import Markdown, display
display(Markdown(relatorio_final.replace('\n', '  \n')))
# Out:
#
# RELATÓRIO TÉCNICO — ANÁLISE DA CARGA ELÉTRICA DE SÃO PAULO
#
# 1. Caracterização do conjunto analisado
# Foi analisada a carga elétrica da área de carga de São Paulo (SP), utilizando os
# dados de Carga Verificada do ONS para o período de 2025-08-01 03:30:00+00:00 a 2025-08-08 03:00:00+00:00.
# O conjunto válido possui 336 medições.
#
# 2. Principais indicadores
# A carga mínima observada foi de 12139.25, enquanto a carga máxima foi de
# 23185.31. A carga média foi de 17870.83 e a mediana foi de
# 18199.13. A amplitude entre o menor e o maior valor foi de
# 11046.06.
#
# O valor máximo ficou 5314.48 acima da média. Portanto, os
# indicadores mostram a distância do pico em relação ao comportamento médio, sem
# atribuir uma causa para essa diferença.
#
# 3. Períodos de alta demanda
# Foi definido como alta demanda todo registro superior a 90% da carga máxima.
# O limiar calculado foi de 20866.78. Foram identificadas
# 50 medições nessa condição, correspondentes a
# 14.88% do total.
#
# O maior valor registrado foi de 23185.31, com ocorrência em
# 2025-08-01 22:00:00+00:00.
#
# 4. Comparação com o segundo critério
# O segundo critério adotado foi carga acima da média. Esse recorte reuniu
# 184 medições, equivalentes a 54.76% do total.
# Em comparação, o critério de alta demanda selecionou 50
# medições (14.88%).
#
# Assim, o critério acima da média abrangeu uma parcela maior do conjunto do que o
# critério de alta demanda, pois este último exige proximidade do valor máximo.
#
# 5. Conclusão
# Os dados analisados mostram a variação da carga elétrica de São Paulo durante o
# período estudado. O pico foi identificado objetivamente a partir do maior valor
# de carga, e os períodos de alta demanda foram definidos pelo limite de 90% desse
# máximo. O segundo recorte, baseado na média, permitiu uma visão mais abrangente
# das observações acima do comportamento central.
#
# As conclusões apresentadas são descritivas e baseadas exclusivamente nos dados
# obtidos e nos indicadores calculados. Não é possível determinar, a partir deste
# conjunto de dados isoladamente, as causas das variações observadas.

# %% [markdown]
# ---
#
# ## Entrega
#
# O notebook deve apresentar:
#
# - consulta à API executada;
# - DataFrame criado;
# - inspeção e organização dos dados;
# - indicadores;
# - pelo menos dois DataFrames derivados por critérios;
# - percentuais;
# - pelo menos dois gráficos;
# - interpretações;
# - síntese para a IA;
# - relatório com apoio do Gemini;
# - validação crítica;
# - versão final revisada.
#
# **Entregue somente este Notebook (.ipynb), com todas as células executadas e os resultados visíveis.**
